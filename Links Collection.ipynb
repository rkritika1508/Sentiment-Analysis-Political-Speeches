# %% [markdown]
# Link: https://eparlib.nic.in/handle/123456789/6/browse?page-token=2d1d323f8c3e&page-token-value=736c7528ed63b9874a20690824001b9d&type=loksabhanumber&submit_browse=Lok+Sabha+Number
#
# Main page of all lok sabhas (1-16) ---> speeches list ----> get their links -----> open the links ----> download the pdfs

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from bs4 import BeautifulSoup
import requests
import math
# %matplotlib inline

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
website = 'https://eparlib.nic.in/handle/123456789/6/browse?page-token=ccdcdf0f8ccb&page-token-value=5f621e68b55db83daa4ebdcd11624225&type=loksabhanumber&submit_browse=Lok+Sabha+Number'

page = requests.get(website, stream=True, verify=False)
soup = BeautifulSoup(page.text, 'html.parser')

# %%
sessions_link = soup.findAll(class_='list-group-item')

# %%
links = []
values = []
for link in sessions_link:
    links.append('https://eparlib.nic.in' + link.find('a')['href'])    
    values.append(link.find('span', class_='badge').contents[0])

# %%
'https://eparlib.nic.in/handle/123456789/6/browse?type=loksabhanumber&sort_by=1&order=ASC&rpp=20&etal=-1&value=01&offset=20'
'https://eparlib.nic.in/handle/123456789/6/browse?type=loksabhanumber&sort_by=1&order=ASC&rpp=20&etal=-1&value=01&offset=40'
# Out:
# 'https://eparlib.nic.in/handle/123456789/6/browse?type=loksabhanumber&sort_by=1&order=ASC&rpp=20&etal=-1&value=01&offset=40'

# %%
links = links[11:]
links
# Out:
# ['https://eparlib.nic.in/handle/123456789/6/browse?type=loksabhanumber&order=ASC&rpp=20&value=12',
#  'https://eparlib.nic.in/handle/123456789/6/browse?type=loksabhanumber&order=ASC&rpp=20&value=13',
#  'https://eparlib.nic.in/handle/123456789/6/browse?type=loksabhanumber&order=ASC&rpp=20&value=14',
#  'https://eparlib.nic.in/handle/123456789/6/browse?type=loksabhanumber&order=ASC&rpp=20&value=15',
#  'https://eparlib.nic.in/handle/123456789/6/browse?type=loksabhanumber&order=ASC&rpp=20&value=16']

# %%
values = values[11:]
values
# Out:
# ['88', '357', '331', '357', '331']

# %%
s = 0
for value in values:
    value = int(value)
    s += value
print(s)
# Out:
# 1464

# %%
def get_transcripts_links_session(link, value):
    total_pages = math.ceil(int(value)/20)
    count = 0
    all_index_pages = [link]
    all_pages = []
    k = 1
    while count<total_pages:
        try:
            page = requests.get(link, stream=True, verify=False)
            soup = BeautifulSoup(page.text, 'html.parser')
            next_page_link = soup.find('a', class_='pull-right')['href']
            #print(next_page_link)
            link = 'https://eparlib.nic.in'+ next_page_link
            all_index_pages.append(link)
        except TypeError:
            k = 1
        count += 1
    
    count = 0
    for link in all_index_pages:
        page = requests.get(link, stream=True, verify=False)
        soup = BeautifulSoup(page.text, 'html.parser')
        table = soup.findAll('table', id='collection_home_sort')
        table_links = table[0].findAll('a')
        for web_link in table_links:
            count += 1
            #print(count, web_link.get('href'))
            all_pages.append(web_link.get('href'))
    return all_pages

# %%
all_pages = []
count = 0
for link in links:
    temp_pages = get_transcripts_links_session(link, values[count])
    all_pages += temp_pages
    count += 1

# %%
df = pd.DataFrame(all_pages)

# %%
df.to_csv('pages.csv')

# %%
df
# Out:
#                                               0
# 0     /handle/123456789/758037?view_type=browse
# 1     /handle/123456789/759038?view_type=browse
# 2     /handle/123456789/759063?view_type=browse
# 3     /handle/123456789/758041?view_type=browse
# 4     /handle/123456789/758038?view_type=browse
# 5     /handle/123456789/758035?view_type=browse
# 6     /handle/123456789/758040?view_type=browse
# 7     /handle/123456789/759042?view_type=browse
# 8     /handle/123456789/759040?view_type=browse
# 9     /handle/123456789/759372?view_type=browse
# 10    /handle/123456789/759039?view_type=browse
# 11    /handle/123456789/759023?view_type=browse
# 12    /handle/123456789/759025?view_type=browse
# 13    /handle/123456789/759428?view_type=browse
# 14    /handle/123456789/759030?view_type=browse
# 15    /handle/123456789/759361?view_type=browse
# 16    /handle/123456789/759402?view_type=browse
# 17    /handle/123456789/759383?view_type=browse
# 18    /handle/123456789/759031?view_type=browse
# 19    /handle/123456789/759036?view_type=browse
# 20    /handle/123456789/759034?view_type=browse
# 21    /handle/123456789/759024?view_type=browse
# 22    /handle/123456789/759032?view_type=browse
# 23    /handle/123456789/759026?view_type=browse
# 24    /handle/123456789/759435?view_type=browse
# 25    /handle/123456789/759395?view_type=browse
# 26    /handle/123456789/759047?view_type=browse
# 27    /handle/123456789/759022?view_type=browse
# 28    /handle/123456789/759043?view_type=browse
# 29    /handle/123456789/759044?view_type=browse
# ...                                         ...
# 1434  /handle/123456789/764513?view_type=browse
# 1435  /handle/123456789/764516?view_type=browse
# 1436  /handle/123456789/764508?view_type=browse
# 1437  /handle/123456789/784189?view_type=browse
# 1438  /handle/123456789/784191?view_type=browse
# 1439  /handle/123456789/784194?view_type=browse
# 1440  /handle/123456789/784188?view_type=browse
# 1441  /handle/123456789/784187?view_type=browse
# 1442  /handle/123456789/784195?view_type=browse
# 1443  /handle/123456789/784190?view_type=browse
# 1444  /handle/123456789/784196?view_type=browse
# 1445  /handle/123456789/784192?view_type=browse
# 1446  /handle/123456789/784619?view_type=browse
# 1447  /handle/123456789/784186?view_type=browse
# 1448  /handle/123456789/784193?view_type=browse
# 1449  /handle/123456789/785177?view_type=browse
# 1450  /handle/123456789/785175?view_type=browse
# 1451  /handle/123456789/785173?view_type=browse
# 1452  /handle/123456789/785176?view_type=browse
# 1453  /handle/123456789/785174?view_type=browse
# 1454  /handle/123456789/785172?view_type=browse
# 1455  /handle/123456789/784620?view_type=browse
# 1456  /handle/123456789/784621?view_type=browse
# 1457  /handle/123456789/785170?view_type=browse
# 1458  /handle/123456789/784622?view_type=browse
# 1459  /handle/123456789/784623?view_type=browse
# 1460  /handle/123456789/784624?view_type=browse
# 1461  /handle/123456789/785171?view_type=browse
# 1462  /handle/123456789/784625?view_type=browse
# 1463  /handle/123456789/785042?view_type=browse
#
# [1464 rows x 1 columns]
